# %% [markdown]
# # Análise dos resultados
#
# Notebook de leitura dos arquivos processados já gerados pelo pipeline.

# %%
import pandas as pd
from pathlib import Path

ROOT = Path('..')
DATA = ROOT / 'data' / 'processed'
VIS = ROOT / 'visualizations'

# %% [markdown]
# ## Cobertura

# %%
pd.read_csv(DATA / 'metadados_cobertura.csv')

# %% [markdown]
# ## Métricas dos modelos

# %%
pd.read_csv(DATA / 'metricas_modelos.csv')

# %% [markdown]
# ## Baseline

# %%
pd.read_csv(DATA / 'metricas_baseline.csv')

# %% [markdown]
# ## Ablação das variáveis de focos

# %%
pd.read_csv(DATA / 'ablacao_focos.csv')

# %% [markdown]
# ## Correlação de Spearman

# %%
pd.read_csv(DATA / 'correlacao_spearman.csv', index_col=0)

# %% [markdown]
# ## Sensibilidade agosto–novembro

# %%
pd.read_csv(DATA / 'sensibilidade_estacao_fogo.csv')
